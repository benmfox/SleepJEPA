# %% [raw]
# ---
# description: disposable cameras are cool, but i dont really understand the point
# output-file: nested.html
# title: Nested Tensors Are Cool
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(unflatten_dim_from_batch)
# Out:
# def unflatten_dim_from_batch(
#     embs, c_in
# ):

# %%
#| echo: false
#| output: asis
show_doc(flatten_dim_to_batch)
# Out:
# def flatten_dim_to_batch(
#     x, dim:int=1
# ):

# %%
#| echo: false
#| output: asis
show_doc(return_nested_dim)
# Out:
# def return_nested_dim(
#     x
# ):

# %%
#| echo: false
#| output: asis
show_doc(coerce_offsets)
# Out:
# def coerce_offsets(
#     src, tgt
# ):
# """
# See https://github.com/pytorch/pytorch/issues/138180
# Coerce offsets to be the same for two nested tensors so element wise operations can occur.
#
# use: src = coerce_offsets(src, tgt)
# """

# %%
#| echo: false
#| output: asis
show_doc(get_predictions_nested_survival)
# Out:
# def get_predictions_nested_survival(
#     data_loader, model, dataloader_name:str='', autocast:bool=True
# ):

# %%
#| echo: false
#| output: asis
show_doc(get_predictions_nested)
# Out:
# def get_predictions_nested(
#     data_loader, model, dataloader_name:str='', autocast:bool=True
# ):

# %%
#| echo: false
#| output: asis
show_doc(get_embeddings_nested)
# Out:
# def get_embeddings_nested(
#     data_loader, model, dataloader_name:str='', autocast:bool=True
# ):
