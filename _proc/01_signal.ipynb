# %% [raw]
# ---
# description: Signal processing utilities that make complete sense
# output-file: signal.html
# title: Signal
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(iqr_normalization)
# Out:
# def iqr_normalization(
#     waveform_array, is_spo2:bool=False
# ):

# %%
#| echo: false
#| output: asis
show_doc(iir_filter)
# Out:
# def iir_filter(
#     waveform_array, freq_range, btype, order:int=16, fs:int=128
# ):
# """
# as described in https://www.researchsquare.com/article/rs-6307069/v1
# """

# %%
#| echo: false
#| output: asis
show_doc(resample_waveform)
# Out:
# def resample_waveform(
#     waveform_array, fs_in, fs_out, is_spo2:bool=False
# ):

# %%
#| echo: false
#| output: asis
show_doc(baseline_filter)
# Out:
# def baseline_filter(
#     data
# ):

# %%
#| echo: false
#| output: asis
show_doc(high_frequency_noise_filter)
# Out:
# def high_frequency_noise_filter(
#     data
# ):

# %%
#| echo: false
#| output: asis
show_doc(butterworth)
# Out:
# def butterworth(
#     waveform_array, freq_range, btype, fs:int=128, order:int=4, # Recommend playing around with the order as well
# ):
